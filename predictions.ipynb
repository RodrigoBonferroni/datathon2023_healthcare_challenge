# %% [markdown]
# # Model Prediction: Temporal Series using clusters for products and hospitals

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, r2_score, mean_squared_error

# %%
# Read the file into a pandas DataFrame
df = pd.read_csv('consumo_material_clusters.csv')  
df.head(10)
# Out:
#    CODIGO      NUMERO  REFERENCIA  CANTIDADCOMPRA  UNIDADESCONSUMOCONTENIDAS  \
# 0      37  1595724/23          16              60                         10
# 1       1    72714/16          38              40                         10
# 2       5    71961/16          40              20                          5
# 3      19    72773/16          18             100                         50
# 4      14    86159/17          19             300                        300
# 5      25    86264/17          11              80                         10
# 6      26    86265/17          10             140                         10
# 7      27    86147/17          47             600                         10
# 8       5    91119/18          40              40                          5
# 9       7    92073/18          45             100                        100
#
#        PRECIO  IMPORTELINEA  \
# 0   62.590000    375.540000
# 1  102.803729    411.214916
# 2   12.100000     48.400000
# ...

# %%
for df in [df]:
  X = df[['CANTIDADCOMPRA', 'UNIDADESCONSUMOCONTENIDAS', 'DAY', 'MONTH', 'YEAR', 'TIPOCOMPRA_Compra menor', 
          'TIPOCOMPRA_Concurso', 'TGL_ALMACENABLE', 'TGL_TRANSITO', 'REGION', 'DEPARTMENT', 'PUR_CLUSTER', 'HOSP_CLUSTER']]

  # Define the target variable
  y = df['PRECIO']

  # Split the data into training and testing sets
  X_train, X_test, y_train, y_test = train_test_split(X, y)

  # Initialize the random forest classifier
  rf_classifier = RandomForestRegressor(n_estimators=100, random_state=42)

  # Train the model
  rf_classifier.fit(X_train, y_train)

  # Make predictions on the test set
  y_pred = rf_classifier.predict(X_test)

  mse = mean_squared_error(y_test, y_pred)
  print(f'Mean Squared Error on test set: {mse}')

  r_squared = r2_score(y_test, y_pred)
  print(f'R-squared on test set: {r_squared}')
  # The larger the R2, the better the regression model fits your observations

  mae = mean_absolute_error(y_test, y_pred)
  print(f'Mean Absolute Error on test set: {mae}')

  print('Max Price: ' + str(df['PRECIO'].max()))
  print('Min Price: ' + str(df['PRECIO'].min()))
# Out:
# Mean Squared Error on test set: 8025.112695607978
# R-squared on test set: 0.8339759071450739
# Mean Absolute Error on test set: 27.490656264402272
# Max Price: 2458.5
# Min Price: 0.989571
